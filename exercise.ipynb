# %%
import numpy
print(numpy.__version__)
# Out:
# 2.4.2

# %%
import numpy as np

# %%
arr=np.array([1500,3000,5000])

# %%
daily_sales=np.array([[10,15,8,12],[5,7,4,6],[2,3,2,4]])

# %%
print(arr.shape)
# Out:
# (3,)

# %%
print(daily_sales.shape)
# Out:
# (3, 4)

# %%
Grace_unit=np.array(daily_sales + 2)

# %%
print(Grace_unit)
# Out:
# [[12 17 10 14]
#  [ 7  9  6  8]
#  [ 4  5  4  6]]

# %%
Multi= np.dot(arr,daily_sales)

# %%
print(Multi)
# Out:
# [40000 58500 34000 56000]

# %%
np.sqrt(daily_sales)
# Out:
# array([[3.16227766, 3.87298335, 2.82842712, 3.46410162],
#        [2.23606798, 2.64575131, 2.        , 2.44948974],
#        [1.41421356, 1.73205081, 1.41421356, 2.        ]])

# %%
smartwatch_sales = daily_sales[0]
print(smartwatch_sales)
# Out:
# [10 15  8 12]

# %%
speakers_thursday_sales = daily_sales[2][3]
print(speakers_thursday_sales)
# Out:
# 4

# %%
subarray = daily_sales[0:2, 0:2]
print(subarray)
# Out:
# [[10 15]
#  [ 5  7]]

# %%
flat_sales = daily_sales.reshape(-1)
print(flat_sales)
# Out:
# [10 15  8 12  5  7  4  6  2  3  2  4]

# %%
sales_2x6 = daily_sales.reshape(2, 6)
print(sales_2x6)
# Out:
# [[10 15  8 12  5  7]
#  [ 4  6  2  3  2  4]]

# %%
discount = np.linspace(0, 100, 10)
print(discount)
# Out:
# [  0.          11.11111111  22.22222222  33.33333333  44.44444444
#   55.55555556  66.66666667  77.77777778  88.88888889 100.        ]

# %%
predicted_sales = np.random.randint(0, 21, size=(3, 4))
print(predicted_sales)
# Out:
# [[16 14 20  9]
#  [12 14 12 14]
#  [ 2  1  6  5]]

# %%
random_values = np.random.rand(5)
print(random_values)
# Out:
# [0.69178078 0.1005427  0.37442894 0.50704342 0.53522929]

# %%
total_items_sold = np.sum(daily_sales)
print(total_items_sold)
# Out:
# 78

# %%
total_per_product = np.sum(daily_sales, axis=1)
print(total_per_product)
# Out:
# [45 22 11]
